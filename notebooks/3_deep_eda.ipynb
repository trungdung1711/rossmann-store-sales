# %% [markdown]
# ## 🧏 Deep EDA to have insights about the dataset (relationship, correlation)

# %% [markdown]
# ### 🎒 Packages

# %%
from pathlib import Path
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### 🚙 Utilities

# %% [markdown]
# ### 📊 Data
