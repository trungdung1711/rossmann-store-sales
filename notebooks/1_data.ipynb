# %% [markdown]
# ## 🚀 Data preparation

# %% [markdown]
# ### 😵‍💫 Activate your environment

# %%
# Activate your environment
# Run it on your terminal please
! conda activate rossmann-store-sales

# %% [markdown]
# ### 🥇 Install Kaggle cli

# %%
# install kaggle cli
# on your terminal please
! conda install kaggle

# %% [markdown]
# ### 📈 Download data from Kaggle

# %%
! rm -rf ../data
# Download the dataset from kaggle
# Remember to join the competition first
# Also remember to generate API credentials
! mkdir ../data
! kaggle competitions download --force rossmann-store-sales --path ../data
! unzip ../data/rossmann-store-sales.zip -d ../data
# Out:
# ...
# 100%|███████████████████████████████████████| 6.99M/6.99M [00:08<00:00, 893kB/s]
#
# Archive:  ../data/rossmann-store-sales.zip
#   inflating: ../data/sample_submission.csv
#   inflating: ../data/store.csv
#   inflating: ../data/test.csv
#   inflating: ../data/train.csv
